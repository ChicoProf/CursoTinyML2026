# %% [markdown]
# # House Pricing Regression using Dense Neural Network (DNN)

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# ## Upload and Explore Dataset
# [The Boston house-price data](http://lib.stat.cmu.edu/datasets/boston)
# * This is a dataset taken from the StatLib library which is maintained at Carnegie Mellon University.
# * There are 506 samples, each one with 13 attributes (Features `Xi` from 0 to 12) of houses at different locations around the Boston suburbs in the late 1970s. The attributes themselves are defined in the StatLib website (as per capta crime rate in the area, number of rooms, distance  from employemment center, etc).
# Below the attributes (or features) in order:
#  - CRIM     per capita crime rate by town
#  - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#  - INDUS    proportion of non-retail business acres per town
#  - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#  - NOX      nitric oxides concentration (parts per 10 million)
#  - RM       average number of rooms per dwelling
#  - AGE      proportion of owner-occupied units built prior to 1940
#  - DIS      weighted distances to five Boston employment centres
#  - RAD      index of accessibility to radial highways
#  - TAX      full-value property-tax rate per $10,000
#  - PTRATIO  pupil-teacher ratio by town
#  - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#  - LSTAT    % lower status of the population
#  MEDV     Median value of owner-occupied homes in \$1000's
# - Target (`Y`) is the median values of the houses at a location (in USD 1,000).
#
# **Goal**
# *  Our goal is to build a regression model that takes these **13 features as input** and **output a single value prediction** of the "median value of owner-occupied homes (in USD 1000)."
# * Dataset can be download direct from: [tf.keras.datasets.boston_housing](https://www.tensorflow.org/api_docs/python/tf/keras/datasets/boston_housing/load_data)

# %%
data = tf.keras.datasets.boston_housing

(x_train, y_train), (x_test, y_test) = data.load_data()
type(data.load_data())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# tuple

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (404, 13)
# (404,)

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (102, 13)
# (102,)

# %%
x_train[0]
# Out:
# array([  1.23247,   0.     ,   8.14   ,   0.     ,   0.538  ,   6.142  ,
#         91.7    ,   3.9769 ,   4.     , 307.     ,  21.     , 396.9    ,
#         18.72   ])

# %%
y_train[10]
# Out:
# np.float64(12.1)

# %% [markdown]
# ### Exploring Target (Y)

# %%
y_train
# Out:
# array([15.2, 42.3, 50. , 21.1, 17.7, 18.5, 11.3, 15.6, 15.6, 14.4, 12.1,
#        17.9, 23.1, 19.9, 15.7,  8.8, 50. , 22.5, 24.1, 27.5, 10.9, 30.8,
#        32.9, 24. , 18.5, 13.3, 22.9, 34.7, 16.6, 17.5, 22.3, 16.1, 14.9,
#        23.1, 34.9, 25. , 13.9, 13.1, 20.4, 20. , 15.2, 24.7, 22.2, 16.7,
#        12.7, 15.6, 18.4, 21. , 30.1, 15.1, 18.7,  9.6, 31.5, 24.8, 19.1,
#        22. , 14.5, 11. , 32. , 29.4, 20.3, 24.4, 14.6, 19.5, 14.1, 14.3,
#        15.6, 10.5,  6.3, 19.3, 19.3, 13.4, 36.4, 17.8, 13.5, 16.5,  8.3,
#        14.3, 16. , 13.4, 28.6, 43.5, 20.2, 22. , 23. , 20.7, 12.5, 48.5,
#        14.6, 13.4, 23.7, 50. , 21.7, 39.8, 38.7, 22.2, 34.9, 22.5, 31.1,
#        28.7, 46. , 41.7, 21. , 26.6, 15. , 24.4, 13.3, 21.2, 11.7, 21.7,
#        19.4, 50. , 22.8, 19.7, 24.7, 36.2, 14.2, 18.9, 18.3, 20.6, 24.6,
#        18.2,  8.7, 44. , 10.4, 13.2, 21.2, 37. , 30.7, 22.9, 20. , 19.3,
#        31.7, 32. , 23.1, 18.8, 10.9, 50. , 19.6,  5. , 14.4, 19.8, 13.8,
#        19.6, 23.9, 24.5, 25. , 19.9, 17.2, 24.6, 13.5, 26.6, 21.4, 11.9,
#        22.6, 19.6,  8.5, 23.7, 23.1, 22.4, 20.5, 23.6, 18.4, 35.2, 23.1,
#        27.9, 20.6, 23.7, 28. , 13.6, 27.1, 23.6, 20.6, 18.2, 21.7, 17.1,
#         8.4, 25.3, 13.8, 22.2, 18.4, 20.7, 31.6, 30.5, 20.3,  8.8, 19.2,
#        19.4, 23.1, 23. , 14.8, 48.8, 22.6, 33.4, 21.1, 13.6, 32.2, 13.1,
#        23.4, 18.9, 23.9, 11.8, 23.3, 22.8, 19.6, 16.7, 13.4, 22.2, 20.4,
#        21.8, 26.4, 14.9, 24.1, 23.8, 12.3, 29.1, 21. , 19.5, 23.3, 23.8,
#        17.8, 11.5, 21.7, 19.9, 25. , 33.4, 28.5, 21.4, 24.3, 27.5, 33.1,
#        16.2, 23.3, 48.3, 22.9, 22.8, 13.1, 12.7, 22.6, 15. , 15.3, 10.5,
#        24. , 18.5, 21.7, 19.5, 33.2, 23.2,  5. , 19.1, 12.7, 22.3, 10.2,
#        13.9, 16.3, 17. , 20.1, 29.9, 17.2, 37.3, 45.4, 17.8, 23.2, 29. ,
#        22. , 18. , 17.4, 34.6, 20.1, 25. , 15.6, 24.8, 28.2, 21.2, 21.4,
#        23.8, 31. , 26.2, 17.4, 37.9, 17.5, 20. ,  8.3, 23.9,  8.4, 13.8,
#         7.2, 11.7, 17.1, 21.6, 50. , 16.1, 20.4, 20.6, 21.4, 20.6, 36.5,
#         8.5, 24.8, 10.8, 21.9, 17.3, 18.9, 36.2, 14.9, 18.2, 33.3, 21.8,
#        19.7, 31.6, 24.8, 19.4, 22.8,  7.5, 44.8, 16.8, 18.7, 50. , 50. ,
#        19.5, 20.1, 50. , 17.2, 20.8, 19.3, 41.3, 20.4, 20.5, 13.8, 16.5,
#        23.9, 20.6, 31.5, 23.3, 16.8, 14. , 33.8, 36.1, 12.8, 18.3, 18.7,
#        19.1, 29. , 30.1, 50. , 50. , 22. , 11.9, 37.6, 50. , 22.7, 20.8,
#        23.5, 27.9, 50. , 19.3, 23.9, 22.6, 15.2, 21.7, 19.2, 43.8, 20.3,
#        33.2, 19.9, 22.5, 32.7, 22. , 17.1, 19. , 15. , 16.1, 25.1, 23.7,
#        28.7, 37.2, 22.6, 16.4, 25. , 29.8, 22.1, 17.4, 18.1, 30.3, 17.5,
#        24.7, 12.6, 26.5, 28.7, 13.3, 10.4, 24.4, 23. , 20. , 17.8,  7. ,
#        11.8, 24.4, 13.8, 19.4, 25.2, 19.4, 19.4, 29.1])

# %%
print('Min price in $K:  ',y_train.min())
print('Mean price in $K:  ',round(y_train.mean(),2))
print('Max price in $K: ',y_train.max())
# Out:
# Min price in $K:   5.0
# Mean price in $K:   22.4
# Max price in $K:  50.0

# %%
plt.hist(y_train, label='train',color='green',alpha=0.8)
plt.hist(y_test, label = 'test',color='yellow')
plt.xlabel('Price in K$')
plt.legend();

# %% [markdown]
# ### Exploring Input Features (X)

# %%
print(len(x_train[0])) #imprime o número de elementos na linha 0
print(len(x_train)) #imprime o número de linhas da matriz
print(len(x_train[:,4])) #imprime o número de linhas na coluna 4
print(len(x_train[4,:])) #imprime o numero de colunas na linha 4
# Out:
# 13
# 404
# 404
# 13

# %%
for i in range(len(x_train[0])): #pra cada elemento da linha 0 da matriz de entrada de treinamento...
  print(f"valor máximo do índice da característica {i} ==> variam de {x_train[:,i].min()} até {x_train[:,i].max()}")

print(f"valores mínimos das características: {[float(x_train[:,i].min()) for i in range(len(x_train[0]))]}")
print(f"valores máximos das características: {[float(x_train[:,i].max()) for i in range(len(x_train[0]))]}")
# Out:
# valor máximo do índice da característica 0 ==> variam de 0.00632 até 88.9762
# valor máximo do índice da característica 1 ==> variam de 0.0 até 100.0
# valor máximo do índice da característica 2 ==> variam de 0.46 até 27.74
# valor máximo do índice da característica 3 ==> variam de 0.0 até 1.0
# valor máximo do índice da característica 4 ==> variam de 0.385 até 0.871
# valor máximo do índice da característica 5 ==> variam de 3.561 até 8.725
# valor máximo do índice da característica 6 ==> variam de 2.9 até 100.0
# valor máximo do índice da característica 7 ==> variam de 1.1296 até 10.7103
# valor máximo do índice da característica 8 ==> variam de 1.0 até 24.0
# valor máximo do índice da característica 9 ==> variam de 188.0 até 711.0
# valor máximo do índice da característica 10 ==> variam de 12.6 até 22.0
# valor máximo do índice da característica 11 ==> variam de 0.32 até 396.9
# valor máximo do índice da característica 12 ==> variam de 1.73 até 37.97
# valores mínimos das características: [0.00632, 0.0, 0.46, 0.0, 0.385, 3.561, 2.9, 1.1296, 1.0, 188.0, 12.6, 0.32, 1.73]
# valores máximos das características: [88.9762, 100.0, 27.74, 1.0, 0.871, 8.725, 100.0, 10.7103, 24.0, 711.0, 22.0, 396.9, 37.97]

# %%
feature = 2
plt.hist(x_train[:,feature], label='train',color='blue')
plt.hist(x_test[:,feature], label = 'test',color='red',alpha=0.6)
plt.legend();

# %%
print (x_train.max())
print (x_train.min())
# Out:
# 711.0
# 0.0

# %% [markdown]
# ### Preprocessing Data
#
# **Normalizing Data**:
# We notice that values range varies depending on the type of the feature. If we are training a neural network, for various reasons it's easier if we treat all values as between 0 and 1 (or at least with similar ranges), a process called 'normalizing'. In this case, all features will be `rescaled`.
#
# The standard score of a sample `x` is calculated as:
#
#         z = (x - u) / s
#
# where `u` is the mean of the training samples or zero if `with_mean=False` and `s` is the standard deviation of the training samples or one if `with_std=False`.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# first we fit the scaler on the training dataset
scaler.fit(x_train)

# then we call the transform method to scale both the training and testing data
x_train_norm = scaler.transform(x_train)
x_test_norm = scaler.transform(x_test)

#não precisava importar uma biblioteca pra fazer isso, pois dá pra se resolver em 3 linhas:
x_train_n=x_train.copy()
for l in range(len(x_train)):
  for c in range(len(x_train[l])):
    x_train_n[l][c]=(x_train_n[l,c]-x_train[:,c].mean())/x_train[:,c].std()

print("na library:")
print(x_train_norm)
print("na mão:")
print(x_train_n)
print(x_train[0,0])
print(x_train[:,0].mean())
print(x_train[:,0].max())
print(x_train[:,0].std())
# Out:
# na library:
# [[-0.27224633 -0.48361547 -0.43576161 ...  1.14850044  0.44807713
#    0.8252202 ]
#  [-0.40342651  2.99178419 -1.33391162 ... -1.71818909  0.43190599
#   -1.32920239]
#  [ 0.1249402  -0.48361547  1.0283258  ...  0.78447637  0.22061726
#   -1.30850006]
#  ...
#  [-0.40202987  0.99079651 -0.7415148  ... -0.71712291  0.07943894
#   -0.67776904]
#  [-0.17292018 -0.48361547  1.24588095 ... -1.71818909 -0.98764362
#    0.42083466]
#  [-0.40422614  2.04394792 -1.20161456 ... -1.30866202  0.23317118
#   -1.15392266]]
# na mão:
# [[-0.27224633 -0.48361547 -0.43576161 ...  1.14850044  0.44807713
#    0.8252202 ]
#  [-0.40342651  2.99178419 -1.33391162 ... -1.71818909  0.43190599
#   -1.32920239]
#  [ 0.1249402  -0.48361547  1.0283258  ...  0.78447637  0.22061726
#   -1.30850006]
#  ...
#  [-0.40202987  0.99079651 -0.7415148  ... -0.71712291  0.07943894
#   -0.67776904]
#  [-0.17292018 -0.48361547  1.24588095 ... -1.71818909 -0.98764362
#    0.42083466]
#  [-0.40422614  2.04394792 -1.20161456 ... -1.30866202  0.23317118
#   -1.15392266]]
# 1.23247
# 3.74511056930693
# 88.9762
# 9.229290727197062

# %% [markdown]
# Another way do normalize data directly with numpy is:
# - Get per-feature statistics (mean, standard deviation) from the training set to normalize by:
#   - x_train_mean = np.mean(x_train, axis=0)
#   - x_train_std = np.std(x_train, axis=0)
#   - x_train_norm = (x_train - x_train_mean) / x_train_std
#
#   - x_test_norm = (x_test - x_train_mean) / x_train_std
#
# **Note** that the quantities used for normalizing the test data are computed using the training data. You should never use in your workflow any quantity computed on the test data, even for something as simple as data normalization.

# %%
print (x_train_norm.max())
print (x_train_norm.min())
print (x_train_n.max())
print (x_train_n.min())
# Out:
# 9.234847178400438
# -3.8172503201932715
# 9.234847178400434
# -3.8172503201932804

# %% [markdown]
# A sample output

# %%
print(x_train_norm[0])
# Out:
# [-0.27224633 -0.48361547 -0.43576161 -0.25683275 -0.1652266  -0.1764426
#   0.81306188  0.1166983  -0.62624905 -0.59517003  1.14850044  0.44807713
#   0.8252202 ]

# %% [markdown]
# ## Define Model

# %%
x_train.shape
# Out:
# (404, 13)

# %%
x_train.shape[1]
# Out:
# 13

# %%
input_shape = x_train.shape[1]
input_shape
# Out:
# 13

# %% [markdown]
# The model should be created, for example with those layers:
# - [input] ==> [hidden] ==> [output]:
#   - 13 ==> [20] ==>  1
#
# The **Input Layer** should be 13 (number of features) and the **Output Layer** shoub be 1 to match the target (y). The number of neurons at **Hidden layers** are arbitrary.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(input_shape,)),
    tf.keras.layers.Dense(20, activation='relu'),
    tf.keras.layers.Dense(1)
    ])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 20)             │           280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 301 (1.18 KB)
#  Trainable params: 301 (1.18 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Input layer has 13 conections, one for each feature [X]. Each feature goes to each one of the neurons of 1st Dense Layer, that has 20 Neurons. So, total parameters 1st Dense Layer will be ws=(13 x 20) + bs=20 ==> 280. The output layer will be only one Neuron that has one input from the output of previous layer (20 ) + 1 b ==> 21.
#
# For simplicity, the input layer can be "merge with 1st layer"

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(20,
                          activation='relu',
                          input_shape = [13]),
    tf.keras.layers.Dense(1)
    ])

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 20)             │           280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 301 (1.18 KB)
#  Trainable params: 301 (1.18 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ##Compile Model

# %% [markdown]
# ### Type of errors
# In statistics, `Mean Absolute Error (MAE)` is a measure of errors between paired observations expressing the same phenomenon. Examples of Y versus X include comparisons of predicted versus observed, subsequent time versus initial time, and one technique of measurement versus an alternative technique of measurement. MAE is calculated as:
#
#
# $$MAE=\frac{1}{n}\sum_{i=1}^{n}(\left|y_{i}-\hat{y}_{i}\right|)$$
#
#
# Another alternative to evaluate regression is the `Root Mean Square Error (RMSE)`.
# This is the root of the  mean of the squared errors. It is a most popular measure of regression model's performance because also keep the same unit as y and larger errors are noted more than with MAE.
#
# $$RSME=\sqrt{\frac{1}{n}\sum_{i=1}^{n}{(y_{i}-\hat{y}_{i})}^2}$$
#
# You can use MSE to calculate loss, but also tracking the MAE or RSME, once those values will have the "same order" of the Target (in the case, multiples of USD1,000).

# %% [markdown]
# The optimizer used is [ADAM](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam), a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments. The hyperparameter "Learning-Rate" used is the default ==> 0.001

# %%
model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae'] # used to monitor the training and testing steps.
    )

# %% [markdown]
# ## Train the model

# %%
history = model.fit(
    x_train_norm,
    y_train,
    epochs=1000,
    verbose=0
    )

# %% [markdown]
# Inspecting the model

# %%
train_eval = model.evaluate(x_train_norm, y_train)
print ("Training data MAE: {:.2}".format(train_eval[1]))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6282 - mae: 1.6768
# Training data MAE: 1.7

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'mae'])

# %%
plt.plot(history.history['loss'], label='MSE')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='upper right')
#plt.ylim([0,50])
plt.show()

# %%
plt.plot(history.history['mae'], label='MAE')
plt.plot(history.history['loss'], label='MSE')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='upper right')
#plt.ylim([0,50])
plt.show()

# %% [markdown]
# ## Testing the trained model

# %%
test_eval = model.evaluate(x_test_norm, y_test)
print ("Test data MAE: {:.2}".format(test_eval[1]))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.1875 - mae: 2.8243
# Test data MAE: 2.8

# %%
rsme = round(np.sqrt(test_eval[0]), 3)
rsme
# Out:
# np.float64(4.38)

# %% [markdown]
# The model has an RSME error of around USD4,000 and an MAE of around USD 2,600, what is very good for house's price estimation.

# %% [markdown]
# Note: With features **not normalized**, we got loss (MSE): 22.0815; RSME: USD4,700 and  MAE: USD3,500

# %%
y_hat = model.predict(x_test_norm)
print(y_hat[:5]) # get the output predict values for the 5 first samples
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[ 7.9832115]
#  [19.533428 ]
#  [22.38768  ]
#  [38.59394  ]
#  [24.448048 ]]

# %%
y_test[:5] # get the output real known values for the 5 first samples
# Out:
# array([ 7.2, 18.8, 19. , 27. , 22.2])

# %%
plt.hist(y_hat, label='predictions', color = 'b')
plt.hist(y_test, label = 'real values', color = 'r', alpha=0.5)
plt.xlabel('Price in K$')
plt.legend();

# %% [markdown]
# ## Doing Inference

# %%
xt = np.array([1.1, 0., 9., 0., 0.6, 7., 92., 3.8 , 4., 300., 21., 200, 19.5])
xt.shape
# Out:
# (13,)

# %%
x_train.shape
# Out:
# (404, 13)

# %%
xt = np.reshape(xt, (1, 13))
xt.shape
# Out:
# (1, 13)

# %%
xt
# Out:
# array([[  1.1,   0. ,   9. ,   0. ,   0.6,   7. ,  92. ,   3.8,   4. ,
#         300. ,  21. , 200. ,  19.5]])

# %%
xt_norm = scaler.transform(xt)
xt_norm
# Out:
# array([[-0.28659955, -0.48361547, -0.30934443, -0.25683275,  0.36401915,
#          1.03386853,  0.82381223,  0.02945662, -0.62624905, -0.63729594,
#          1.14850044, -1.64672402,  0.93287232]])

# %%
yt = model.predict(xt_norm)
yt
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# array([[15.540718]], dtype=float32)

# %%
xt = np.array([1.1, 0., 9., 0., 0.6, 7., 92., 3.8 , 4., 300., 21., 200, 19.5])
xt = np.reshape(xt, (1, 13))
xt_norm = scaler.transform(xt)
yt = model.predict(xt_norm)
print("The predict value for this house is US${:.2f} thousand".format(yt[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# The predict value for this house is US$15.54 thousand

# %% [markdown]
# # Extra
# ## Finding the correct Hyperparameters
# - [KerasTuner](https://keras.io/keras_tuner/)
#
# KerasTuner is an easy-to-use, scalable hyperparameter optimization framework that solves the pain points of hyperparameter search.

# %%
# !pip install keras-tuner --upgrade
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.8-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (3.13.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (26.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (2.32.4)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (1.81.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (5.29.6)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio->keras-tuner) (4.15.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (3.16.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.19.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (2026.6.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras->keras-tuner) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras->keras-tuner) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.8-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 3.3 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.8 kt-legacy-1.0.5

# %%
import tensorflow as tf
import keras_tuner as kt

# %%
data = tf.keras.datasets.boston_housing
(x_train, y_train), (x_test, y_test) = data.load_data()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# first we fit the scaler on the training dataset
scaler.fit(x_train)

# then we call the transform method to scale both the training and testing data
x_train_norm = scaler.transform(x_train)
x_test_norm = scaler.transform(x_test)

# %% [markdown]
# Write a function that creates and returns a Keras model. Use the `hp` argument to define the hyperparameters during model creation.

# %%
def build_model(hp):
  model = tf.keras.Sequential()
  model.add(tf.keras.layers.Dense(
      hp.Choice('units', [10, 20, 30]),
      activation='relu'))

  model.add(tf.keras.layers.Dense(1))
  model.compile(optimizer='adam', loss='mse')
  return model

# %% [markdown]
# Initialize a tuner (here, RandomSearch). We use objective to specify the objective to select the best models, and we use max_trials to specify the number of different models to try.

# %%
tuner = kt.RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=5)

# %% [markdown]
# Start the search and get the best model:

# %%
tuner.search(
    x_train_norm, y_train,
    epochs=500,
    validation_data=(x_test_norm, y_test))

best_model = tuner.get_best_models()[0]
# Out:
# Trial 1 Complete [00h 01m 24s]
# val_loss: 58.9316291809082
#
# Best val_loss So Far: 58.9316291809082
# Total elapsed time: 00h 01m 24s
#
# Search: Running Trial #2
#
# Value             |Best Value So Far |Hyperparameter
# 30                |10                |units
#
# Epoch 1/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 573.3190 - val_loss: 592.2151
# Epoch 2/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 558.7311 - val_loss: 577.2753
# Epoch 3/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 544.0336 - val_loss: 561.8476
# Epoch 4/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 528.5369 - val_loss: 545.7863
# Epoch 5/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 512.7512 - val_loss: 528.5645
# Epoch 6/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 495.1786 - val_loss: 510.4169
# Epoch 7/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 476.8438 - val_loss: 490.9636
# Epoch 8/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 457.2865 - val_loss: 470.3351
# Epoch 9/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 436.8937 - val_loss: 448.7616
# Epoch 10/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 415.9256 - val_loss: 426.2299
# Epoch 11/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 394.2021 - val_loss: 403.2577
# Epoch 12/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 372.4165 - val_loss: 380.3137
# Epoch 13/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 350.4016 - val_loss: 357.4553
# Epoch 14/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 328.5512 - val_loss: 334.9845
# Epoch 15/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 306.5555 - val_loss: 313.3896
# Epoch 16/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 286.4001 - val_loss: 291.5504
# Epoch 17/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 265.9017 - val_loss: 271.2041
# Epoch 18/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 247.0539 - val_loss: 251.8339
# Epoch 19/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 229.3841 - val_loss: 233.7339
# Epoch 20/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 212.7577 - val_loss: 217.1102
# Epoch 21/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 197.6570 - val_loss: 201.6714
# Epoch 22/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 183.6849 - val_loss: 187.3951
# Epoch 23/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 170.9075 - val_loss: 174.2030
# Epoch 24/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 158.9466 - val_loss: 162.3325
# Epoch 25/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 148.0769 - val_loss: 151.3476
# Epoch 26/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 138.0432 - val_loss: 141.1346
# Epoch 27/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 128.7601 - val_loss: 131.7821
# Epoch 28/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 120.4258 - val_loss: 122.6846
# Epoch 29/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 112.3368 - val_loss: 114.4940
# Epoch 30/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 104.7937 - val_loss: 107.0542
# Epoch 31/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 98.0499 - val_loss: 100.1535
# Epoch 32/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 91.6382 - val_loss: 93.7734
# Epoch 33/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 85.8586 - val_loss: 87.6926
# Epoch 34/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 80.3166 - val_loss: 82.1556
# Epoch 35/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 75.2245 - val_loss: 77.1087
# Epoch 36/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 70.3459 - val_loss: 72.5614
# Epoch 37/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 65.9204 - val_loss: 68.5038
# Epoch 38/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 62.0188 - val_loss: 64.4089
# Epoch 39/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 58.1726 - val_loss: 60.8535
# Epoch 40/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 54.7799 - val_loss: 57.5532
# Epoch 41/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 51.6238 - val_loss: 54.5850
# Epoch 42/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 48.6403 - val_loss: 52.0073
# Epoch 43/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 46.0992 - val_loss: 49.4651
# Epoch 44/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 43.7112 - val_loss: 47.2545
# Epoch 45/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 41.6010 - val_loss: 45.2661
# Epoch 46/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 39.5594 - val_loss: 43.5157
# Epoch 47/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 37.8685 - val_loss: 41.9969
# Epoch 48/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 36.3343 - val_loss: 40.5753
# Epoch 49/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 34.9473 - val_loss: 39.3650
# Epoch 50/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 33.7185 - val_loss: 38.3001
# Epoch 51/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 32.6188 - val_loss: 37.3540
# Epoch 52/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 31.6351 - val_loss: 36.5203
# Epoch 53/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 30.7329 - val_loss: 35.8318
# Epoch 54/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 30.0120 - val_loss: 35.1253
# Epoch 55/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 29.3523 - val_loss: 34.5044
# Epoch 56/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 28.7037 - val_loss: 33.9228
# Epoch 57/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 28.1792 - val_loss: 33.4521
# Epoch 58/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 27.6034 - val_loss: 33.0560
# Epoch 59/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 27.1990 - val_loss: 32.5029
# Epoch 60/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 26.7632 - val_loss: 32.1598
# Epoch 61/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 26.3533 - val_loss: 31.8385
# Epoch 62/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 25.9885 - val_loss: 31.4916
# Epoch 63/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 25.6823 - val_loss: 31.2454
# Epoch 64/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 25.3247 - val_loss: 30.9171
# Epoch 65/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 25.0463 - val_loss: 30.6130
# Epoch 66/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 24.7184 - val_loss: 30.3701
# Epoch 67/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 24.4739 - val_loss: 30.2169
# Epoch 68/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 24.1993 - val_loss: 29.9316
# Epoch 69/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 23.9534 - val_loss: 29.7123
# Epoch 70/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.6867 - val_loss: 29.5783
# Epoch 71/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.4650 - val_loss: 29.3790
# Epoch 72/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 23.2156 - val_loss: 29.1668
# Epoch 73/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 22.9925 - val_loss: 28.9654
# Epoch 74/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 22.8090 - val_loss: 28.7802
# Epoch 75/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 22.5616 - val_loss: 28.5146
# Epoch 76/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 22.3690 - val_loss: 28.2697
# Epoch 77/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.1713 - val_loss: 28.1188
# Epoch 78/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 21.9649 - val_loss: 27.9329
# Epoch 79/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 21.7694 - val_loss: 27.8083
# Epoch 80/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 21.5769 - val_loss: 27.6326
# Epoch 81/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 21.3817 - val_loss: 27.4332
# Epoch 82/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 21.1950 - val_loss: 27.2535
# Epoch 83/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 21.0219 - val_loss: 27.1598
# Epoch 84/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 20.8235 - val_loss: 27.0566
# Epoch 85/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 20.6690 - val_loss: 27.0158
# Epoch 86/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 20.4890 - val_loss: 26.7759
# Epoch 87/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 20.3309 - val_loss: 26.6759
# Epoch 88/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 20.1561 - val_loss: 26.6042
# Epoch 89/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.9833 - val_loss: 26.4242
# Epoch 90/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.8221 - val_loss: 26.3367
# Epoch 91/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 19.6566 - val_loss: 26.2351
# Epoch 92/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.5092 - val_loss: 26.1547
# Epoch 93/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.3235 - val_loss: 26.0101
# Epoch 94/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.1682 - val_loss: 25.9141
# Epoch 95/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.0455 - val_loss: 25.9191
# Epoch 96/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.8718 - val_loss: 25.6672
# Epoch 97/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.7462 - val_loss: 25.4422
# Epoch 98/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.5938 - val_loss: 25.5142
# Epoch 99/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.4366 - val_loss: 25.4377
# Epoch 100/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.3070 - val_loss: 25.1966
# Epoch 101/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.1516 - val_loss: 25.1255
# Epoch 102/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.0111 - val_loss: 25.1575
# Epoch 103/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 17.8727 - val_loss: 25.0408
# Epoch 104/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.7732 - val_loss: 25.0905
# Epoch 105/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.5881 - val_loss: 24.9383
# Epoch 106/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.4613 - val_loss: 24.8220
# Epoch 107/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.3141 - val_loss: 24.6796
# Epoch 108/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.2010 - val_loss: 24.4644
# Epoch 109/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.0631 - val_loss: 24.4864
# Epoch 110/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.9464 - val_loss: 24.4944
# Epoch 111/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 16.8106 - val_loss: 24.4353
# Epoch 112/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.6784 - val_loss: 24.2599
# Epoch 113/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.5399 - val_loss: 24.1928
# Epoch 114/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.4147 - val_loss: 24.2209
# Epoch 115/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.2779 - val_loss: 24.1341
# Epoch 116/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.1595 - val_loss: 24.1388
# Epoch 117/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.0300 - val_loss: 23.9325
# Epoch 118/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 15.8887 - val_loss: 23.8887
# Epoch 119/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.7672 - val_loss: 23.7601
# Epoch 120/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 15.6384 - val_loss: 23.6413
# Epoch 121/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.5254 - val_loss: 23.7296
# Epoch 122/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.4073 - val_loss: 23.6985
# Epoch 123/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.2737 - val_loss: 23.7054
# Epoch 124/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.1598 - val_loss: 23.6882
# Epoch 125/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.0399 - val_loss: 23.5713
# Epoch 126/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.9493 - val_loss: 23.4065
# Epoch 127/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.8111 - val_loss: 23.4614
# Epoch 128/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.7074 - val_loss: 23.4306
# Epoch 129/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.6125 - val_loss: 23.4880
# Epoch 130/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.4917 - val_loss: 23.2793
# Epoch 131/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.3635 - val_loss: 23.2802
# Epoch 132/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.2660 - val_loss: 23.2793
# Epoch 133/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.1526 - val_loss: 23.2806
# Epoch 134/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 14.0517 - val_loss: 23.2106
# Epoch 135/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.9590 - val_loss: 23.1815
# Epoch 136/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.8555 - val_loss: 23.0309
# Epoch 137/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.7556 - val_loss: 23.0921
# Epoch 138/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.6405 - val_loss: 22.9775
# Epoch 139/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.5529 - val_loss: 22.9956
# Epoch 140/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.4421 - val_loss: 22.8622
# Epoch 141/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.3640 - val_loss: 22.7620
# Epoch 142/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.2556 - val_loss: 22.9483
# Epoch 143/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.1556 - val_loss: 22.8318
# Epoch 144/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.0729 - val_loss: 22.7964
# Epoch 145/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 12.9899 - val_loss: 22.6194
# Epoch 146/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.9388 - val_loss: 22.9741
# Epoch 147/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.7923 - val_loss: 22.7869
# Epoch 148/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.6991 - val_loss: 22.6784
# Epoch 149/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.6207 - val_loss: 22.6753
# Epoch 150/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.5518 - val_loss: 22.7351
# Epoch 151/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.4454 - val_loss: 22.6075
# Epoch 152/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.3810 - val_loss: 22.7057
# Epoch 153/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.2997 - val_loss: 22.5019
# Epoch 154/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.2226 - val_loss: 22.5619
# Epoch 155/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.1446 - val_loss: 22.5639
# Epoch 156/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.0634 - val_loss: 22.4787
# Epoch 157/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.9912 - val_loss: 22.5207
# Epoch 158/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.9108 - val_loss: 22.5081
# Epoch 159/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.8341 - val_loss: 22.4136
# Epoch 160/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.7683 - val_loss: 22.4642
# Epoch 161/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.7009 - val_loss: 22.2986
# Epoch 162/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.6312 - val_loss: 22.3828
# Epoch 163/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.5618 - val_loss: 22.2477
# Epoch 164/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 11.4848 - val_loss: 22.3335
# Epoch 165/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.4128 - val_loss: 22.3584
# Epoch 166/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.3391 - val_loss: 22.3282
# Epoch 167/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 11.2805 - val_loss: 22.3220
# Epoch 168/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 11.2105 - val_loss: 22.2961
# Epoch 169/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 11.1389 - val_loss: 22.2221
# Epoch 170/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 11.0830 - val_loss: 22.2405
# Epoch 171/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 11.0297 - val_loss: 22.3283
# Epoch 172/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.9701 - val_loss: 22.4014
# Epoch 173/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10.8870 - val_loss: 22.4192
# Epoch 174/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.8277 - val_loss: 22.3127
# Epoch 175/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 10.7625 - val_loss: 22.1621
# Epoch 176/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.7205 - val_loss: 22.3212
# Epoch 177/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.6573 - val_loss: 22.4393
# Epoch 178/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.6059 - val_loss: 22.4618
# Epoch 179/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.5497 - val_loss: 22.2143
# Epoch 180/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.5044 - val_loss: 22.0987
# Epoch 181/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.4596 - val_loss: 22.3109
# Epoch 182/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.4124 - val_loss: 22.2917
# Epoch 183/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.3824 - val_loss: 22.5550
# Epoch 184/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.3121 - val_loss: 22.3581
# Epoch 185/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.2795 - val_loss: 22.1628
# Epoch 186/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.2319 - val_loss: 22.3327
# Epoch 187/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.2157 - val_loss: 22.1626
# Epoch 188/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.1773 - val_loss: 22.6557
# Epoch 189/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.1096 - val_loss: 22.3479
# Epoch 190/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.0705 - val_loss: 22.2714
# Epoch 191/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.0232 - val_loss: 22.4471
# Epoch 192/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.0052 - val_loss: 22.5725
# Epoch 193/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9463 - val_loss: 22.4562
# Epoch 194/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9192 - val_loss: 22.2232
# Epoch 195/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9048 - val_loss: 22.4926
# Epoch 196/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8415 - val_loss: 22.2814
# Epoch 197/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8069 - val_loss: 22.2996
# Epoch 198/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7778 - val_loss: 22.3819
# Epoch 199/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7920 - val_loss: 22.1103
# Epoch 200/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7041 - val_loss: 22.3381
# Epoch 201/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6865 - val_loss: 22.4806
# Epoch 202/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6474 - val_loss: 22.2615
# Epoch 203/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6418 - val_loss: 22.3564
# Epoch 204/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5711 - val_loss: 22.2872
# Epoch 205/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5756 - val_loss: 21.9783
# Epoch 206/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5446 - val_loss: 22.1761
# Epoch 207/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.5046 - val_loss: 22.3151
# Epoch 208/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4974 - val_loss: 22.2059
# Epoch 209/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4429 - val_loss: 22.1559
# Epoch 210/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4225 - val_loss: 22.4834
# Epoch 211/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3855 - val_loss: 22.3621
# Epoch 212/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3938 - val_loss: 22.0544
# Epoch 213/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3697 - val_loss: 22.3404
# Epoch 214/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3354 - val_loss: 22.0165
# Epoch 215/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2992 - val_loss: 22.0800
# Epoch 216/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2662 - val_loss: 22.4462
# Epoch 217/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2613 - val_loss: 22.4307
# Epoch 218/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2391 - val_loss: 22.2618
# Epoch 219/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2094 - val_loss: 22.0432
# Epoch 220/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1742 - val_loss: 21.9807
# Epoch 221/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1663 - val_loss: 22.3432
# Epoch 222/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1772 - val_loss: 22.5443
# Epoch 223/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1107 - val_loss: 22.1260
# Epoch 224/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0872 - val_loss: 22.1540
# Epoch 225/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.0702 - val_loss: 21.9190
# Epoch 226/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0446 - val_loss: 22.1103
# Epoch 227/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0245 - val_loss: 22.1986
# Epoch 228/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9966 - val_loss: 22.1647
# Epoch 229/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9796 - val_loss: 21.9620
# Epoch 230/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9550 - val_loss: 22.0494
# Epoch 231/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9414 - val_loss: 22.1167
# Epoch 232/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9262 - val_loss: 22.0660
# Epoch 233/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.9066 - val_loss: 22.1953
# Epoch 234/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8902 - val_loss: 21.9287
# Epoch 235/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.8856 - val_loss: 21.8960
# Epoch 236/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8562 - val_loss: 22.0023
# Epoch 237/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8434 - val_loss: 21.9830
# Epoch 238/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.8321 - val_loss: 21.7923
# Epoch 239/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7999 - val_loss: 21.9939
# Epoch 240/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7940 - val_loss: 21.8360
# Epoch 241/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.7559 - val_loss: 22.0750
# Epoch 242/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7445 - val_loss: 22.0765
# Epoch 243/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7321 - val_loss: 22.0316
# Epoch 244/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7175 - val_loss: 21.9539
# Epoch 245/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6892 - val_loss: 22.1403
# Epoch 246/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6840 - val_loss: 22.0284
# Epoch 247/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6622 - val_loss: 22.0326
# Epoch 248/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6519 - val_loss: 21.8155
# Epoch 249/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.6183 - val_loss: 22.0867
# Epoch 250/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6299 - val_loss: 22.0669
# Epoch 251/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5832 - val_loss: 21.9572
# Epoch 252/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.5819 - val_loss: 21.8730
# Epoch 253/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.5854 - val_loss: 21.8339
# Epoch 254/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.5400 - val_loss: 21.8316
# Epoch 255/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.5217 - val_loss: 21.9125
# Epoch 256/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.5120 - val_loss: 21.9224
# Epoch 257/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.5299 - val_loss: 22.0879
# Epoch 258/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.4951 - val_loss: 21.6656
# Epoch 259/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.4678 - val_loss: 21.7182
# Epoch 260/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.4723 - val_loss: 21.5408
# Epoch 261/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.4390 - val_loss: 21.8366
# Epoch 262/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.4262 - val_loss: 21.9333
# Epoch 263/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.4083 - val_loss: 21.7429
# Epoch 264/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.4194 - val_loss: 21.7852
# Epoch 265/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.3757 - val_loss: 21.5918
# Epoch 266/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.3702 - val_loss: 21.4388
# Epoch 267/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.3723 - val_loss: 21.4115
# Epoch 268/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.3412 - val_loss: 21.8868
# Epoch 269/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.3264 - val_loss: 21.8682
# Epoch 270/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3160 - val_loss: 21.7545
# Epoch 271/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.2999 - val_loss: 21.7733
# Epoch 272/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.2796 - val_loss: 21.5629
# Epoch 273/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.2662 - val_loss: 21.5779
# Epoch 274/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2566 - val_loss: 21.7700
# Epoch 275/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.2402 - val_loss: 21.5390
# Epoch 276/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2341 - val_loss: 21.5013
# Epoch 277/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2007 - val_loss: 21.5250
# Epoch 278/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.1892 - val_loss: 21.6149
# Epoch 279/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.2283 - val_loss: 21.3941
# Epoch 280/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1990 - val_loss: 21.7571
# Epoch 281/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.1467 - val_loss: 21.4693
# Epoch 282/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1467 - val_loss: 21.4853
# Epoch 283/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1241 - val_loss: 21.4371
# Epoch 284/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.1183 - val_loss: 21.5472
# Epoch 285/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.1195 - val_loss: 21.2631
# Epoch 286/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0755 - val_loss: 21.5758
# Epoch 287/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0568 - val_loss: 21.2359
# Epoch 288/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0264 - val_loss: 21.3595
# Epoch 289/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0141 - val_loss: 21.5487
# Epoch 290/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0213 - val_loss: 21.8024
# Epoch 291/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.9894 - val_loss: 21.5724
# Epoch 292/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0200 - val_loss: 21.8934
# Epoch 293/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.9949 - val_loss: 21.2950
# Epoch 294/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9673 - val_loss: 21.2213
# Epoch 295/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9605 - val_loss: 21.4979
# Epoch 296/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9110 - val_loss: 21.4978
# Epoch 297/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.9284 - val_loss: 21.1803
# Epoch 298/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8816 - val_loss: 21.3477
# Epoch 299/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9086 - val_loss: 21.6799
# Epoch 300/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8590 - val_loss: 21.2391
# Epoch 301/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8399 - val_loss: 21.2024
# Epoch 302/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8377 - val_loss: 21.3033
# Epoch 303/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8258 - val_loss: 21.4568
# Epoch 304/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7919 - val_loss: 21.2370
# Epoch 305/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7914 - val_loss: 21.4653
# Epoch 306/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7534 - val_loss: 21.2211
# Epoch 307/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7511 - val_loss: 21.1623
# Epoch 308/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7348 - val_loss: 21.2488
# Epoch 309/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7249 - val_loss: 21.3914
# Epoch 310/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7234 - val_loss: 21.4066
# Epoch 311/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6924 - val_loss: 21.3367
# Epoch 312/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7310 - val_loss: 20.9259
# Epoch 313/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6733 - val_loss: 21.4180
# Epoch 314/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6473 - val_loss: 21.3530
# Epoch 315/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6707 - val_loss: 21.1576
# Epoch 316/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6423 - val_loss: 20.9977
# Epoch 317/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6137 - val_loss: 21.1615
# Epoch 318/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6033 - val_loss: 21.3829
# Epoch 319/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6144 - val_loss: 21.4891
# Epoch 320/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5753 - val_loss: 20.9766
# Epoch 321/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5836 - val_loss: 20.9512
# Epoch 322/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5497 - val_loss: 21.0642
# Epoch 323/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5761 - val_loss: 21.4056
# Epoch 324/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5287 - val_loss: 21.1280
# Epoch 325/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5153 - val_loss: 20.9567
# Epoch 326/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5639 - val_loss: 21.5014
# Epoch 327/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4872 - val_loss: 21.2879
# Epoch 328/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5029 - val_loss: 20.7220
# Epoch 329/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4697 - val_loss: 20.7801
# Epoch 330/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4413 - val_loss: 21.0714
# Epoch 331/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.4364 - val_loss: 21.1528
# Epoch 332/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.4418 - val_loss: 20.8454
# Epoch 333/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.4124 - val_loss: 21.0778
# Epoch 334/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.4225 - val_loss: 21.5210
# Epoch 335/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4037 - val_loss: 21.1289
# Epoch 336/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3863 - val_loss: 20.9321
# Epoch 337/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3938 - val_loss: 21.2030
# Epoch 338/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3691 - val_loss: 21.1076
# Epoch 339/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3632 - val_loss: 20.8217
# Epoch 340/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3540 - val_loss: 21.1317
# Epoch 341/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3402 - val_loss: 20.9311
# Epoch 342/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3146 - val_loss: 21.1340
# Epoch 343/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3222 - val_loss: 20.8478
# Epoch 344/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2968 - val_loss: 20.8958
# Epoch 345/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3423 - val_loss: 21.0914
# Epoch 346/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2858 - val_loss: 20.9125
# Epoch 347/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2686 - val_loss: 20.9037
# Epoch 348/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.2472 - val_loss: 21.0283
# Epoch 349/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.2345 - val_loss: 20.8760
# Epoch 350/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.2512 - val_loss: 20.5859
# Epoch 351/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.2204 - val_loss: 20.8625
# Epoch 352/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.2024 - val_loss: 20.9351
# Epoch 353/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.2099 - val_loss: 20.7906
# Epoch 354/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.1815 - val_loss: 20.7858
# Epoch 355/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.2096 - val_loss: 20.8278
# Epoch 356/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.1811 - val_loss: 21.0093
# Epoch 357/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.1753 - val_loss: 20.6310
# Epoch 358/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.1420 - val_loss: 20.7549
# Epoch 359/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.1458 - val_loss: 20.7329
# Epoch 360/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.1226 - val_loss: 20.6231
# Epoch 361/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1177 - val_loss: 20.6400
# Epoch 362/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1113 - val_loss: 20.6883
# Epoch 363/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1021 - val_loss: 20.6787
# Epoch 364/500
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 5.5424
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_887/1263634154.py in <cell line: 0>()
# ----> 1 tuner.search(
#       2     x_train_norm, y_train,
#       3     epochs=500,
#       4     validation_data=(x_test_norm, y_test))
#       5
#
# /usr/local/lib/python3.12/dist-packages/keras_tuner/src/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     232
#     233             self.on_trial_begin(trial)
# --> 234             self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235             self.on_trial_end(trial)
#     236         self.on_search_end()
#
# /usr/local/lib/python3.12/dist-packages/keras_tuner/src/engine/base_tuner.py in _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272     def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273         try:
# --> 274             self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275             trial.status = trial_module.TrialStatus.COMPLETED
#     276             return
#
# /usr/local/lib/python3.12/dist-packages/keras_tuner/src/engine/base_tuner.py in _run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     237
#     238     def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239         results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240         if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241             self.oracle.objective.name
#
# /usr/local/lib/python3.12/dist-packages/keras_tuner/src/engine/tuner.py in run_trial(self, trial, *args, **kwargs)
#     312             callbacks.append(model_checkpoint)
#     313             copied_kwargs["callbacks"] = callbacks
# --> 314             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     315
#     316             histories.append(obj_value)
#
# /usr/local/lib/python3.12/dist-packages/keras_tuner/src/engine/tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     231         hp = trial.hyperparameters
#     232         model = self._try_build(hp)
# --> 233         results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     234
#     235         # Save the build config for model loading later.
#
# /usr/local/lib/python3.12/dist-packages/keras_tuner/src/engine/hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     147             If return a float, it should be the `objective` value.
#     148         """
# --> 149         return model.fit(*args, **kwargs)
#     150
#     151
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     421                         shuffle=False,
#     422                     )
# --> 423                 val_logs = self.evaluate(
#     424                     x=val_x,
#     425                     y=val_y,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     507         self.reset_metrics()
#     508         with epoch_iterator.catch_stop_iteration():
# --> 509             for begin_step, end_step, iterator in epoch_iterator:
#     510                 callbacks.on_test_batch_begin(begin_step)
#     511                 logs = self.test_function(iterator)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in __next__(self)
#     762
#     763     def __next__(self):
# --> 764         return next(self._epoch_iterator)
#     765
#     766     @contextlib.contextmanager
#
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py in _enumerate_iterator(self)
#     123                 )
#     124             if self._num_batches and self._steps_seen >= self._num_batches:
# --> 125                 self._current_iterator = iter(self._get_iterator())
#     126                 self._steps_seen = 0
#     127         else:
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     499     if context.executing_eagerly() or ops.inside_function():
#     500       with ops.colocate_with(self._variant_tensor):
# --> 501         return iterator_ops.OwnedIterator(self)
#     502     else:
#     503       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     707             "When `dataset` is provided, `element_spec` and `components` must "
#     708             "not be specified.")
# --> 709       self._create_iterator(dataset)
#     710
#     711     self._get_next_call_count = 0
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     746             self._flat_output_types)
#     747         self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     749
#     750   def __iter__(self):
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3476   if tld.is_eager:
#    3477     try:
# -> 3478       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479         _ctx, "MakeIterator", name, dataset, iterator)
#    3480       return _result
#
# KeyboardInterrupt:

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 1
# units (Choice)
# {'default': 10, 'conditions': [], 'values': [10, 20, 30], 'ordered': True}

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in ./untitled_project
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 0 summary
# Hyperparameters:
# units: 10
# Score: 58.9316291809082
#
# Trial 1 summary
# Hyperparameters:
# units: 30
